# %% [markdown]
# Programming Question: Heart Attack Prediction

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/heart.csv')
print(df)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# 1. Create and compile as many plots as you can using the matplotlib library for the given dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (20,20))
sns.pairplot(df, hue = 'target')
plt.show()

# %% [markdown]
# 2. Use the created plots to try to find some numerical features that can be used for good classification models (similar to the example in class find features that help in linearly separating data).

# %% [markdown]
# Numerical Features:
# - age x trestbps
# - age x chol
# - age x thalach
# - trestbps x thalach
# - chol x thalach

# %%
Y = df[['target']]
X = df[['age', 'trestbps']]
X2 = df[['age', 'chol']]
X3 = df[['age','thalach']]
X4 = df[['trestbps', 'thalach']]
X5 = df[['chol', 'thalach']]
print(Y.shape)
print(X.shape)
print(X2.shape)
print(X3.shape)
print(X4.shape)
print(X5.shape)
# Out:
# (303, 1)
# (303, 2)
# (303, 2)
# (303, 2)
# (303, 2)
# (303, 2)

# %% [markdown]
# 3. Split the data set into 70% train and 30% test.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, stratify = Y)
print(y_train)
# Out:
#      target
# 217       0
# 169       0
# 163       1
# 226       0
# 218       0
# ..      ...
# 164       1
# 154       1
# 202       0
# 19        1
# 34        1
#
# [212 rows x 1 columns]

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, Y, test_size = 0.3, stratify = Y)

# %%
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, Y, test_size = 0.3, stratify = Y)

# %%
X_train4, X_test4, y_train4, y_test4 = train_test_split(X4, Y, test_size = 0.3, stratify = Y)

# %%
X_train5, X_test5, y_train5, y_test5 = train_test_split(X5, Y, test_size = 0.3, stratify = Y)

# %% [markdown]
# 4. Implement the Logistic Regression classification algorithm.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

model_1 = LogisticRegression()
model_1.fit(X_train, np.squeeze(y_train))
pred = model_1.predict(X_test)
print("Precision: ", precision_score(y_test, pred))
print("Recall: ", recall_score(y_test, pred))
print("Accuracy: ", accuracy_score(y_test, pred))
print("F1 Score: ", f1_score(y_test, pred))
# Out:
# Precision:  0.6470588235294118
# Recall:  0.66
# Accuracy:  0.6153846153846154
# F1 Score:  0.6534653465346535

# %%
model_2 = LogisticRegression()
model_2.fit(X_train2, np.squeeze(y_train2))
pred2 = model_2.predict(X_test2)
print("Precision: ", precision_score(y_test2, pred2))
print("Recall: ", recall_score(y_test2, pred2))
print("Accuracy: ", accuracy_score(y_test2, pred2))
print("F1 Score: ", f1_score(y_test2, pred2))
# Out:
# Precision:  0.6909090909090909
# Recall:  0.76
# Accuracy:  0.6813186813186813
# F1 Score:  0.7238095238095238

# %%
model_3 = LogisticRegression()
model_3.fit(X_train3, np.squeeze(y_train3))
pred3 = model_3.predict(X_test3)
print("Precision: ", precision_score(y_test3, pred3))
print("Recall: ", recall_score(y_test3, pred3))
print("Accuracy: ", accuracy_score(y_test3, pred3))
print("F1 Score: ", f1_score(y_test3, pred3))
# Out:
# Precision:  0.6938775510204082
# Recall:  0.68
# Accuracy:  0.6593406593406593
# F1 Score:  0.686868686868687

# %%
model_4 = LogisticRegression()
model_4.fit(X_train4, np.squeeze(y_train4))
pred4 = model_4.predict(X_test4)
print("Precision: ", precision_score(y_test4, pred4))
print("Recall: ", recall_score(y_test4, pred4))
print("Accuracy: ", accuracy_score(y_test4, pred4))
print("F1 Score: ", f1_score(y_test4, pred4))
# Out:
# Precision:  0.7017543859649122
# Recall:  0.8
# Accuracy:  0.7032967032967034
# F1 Score:  0.7476635514018691

# %%
model_5 = LogisticRegression()
model_5.fit(X_train5, np.squeeze(y_train5))
pred5 = model_5.predict(X_test5)
print("Precision: ", precision_score(y_test5, pred5))
print("Recall: ", recall_score(y_test5, pred5))
print("Accuracy: ", accuracy_score(y_test5, pred5))
print("F1 Score: ", f1_score(y_test5, pred5))
# Out:
# Precision:  0.7090909090909091
# Recall:  0.78
# Accuracy:  0.7032967032967034
# F1 Score:  0.7428571428571428

# %% [markdown]
# 5. Use the evaluation metrics discussed in the class to see how well your models have performed for the given dataset.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# Initializing and train the logistic regression 'model'
model = LogisticRegression()
model.fit(X_train, y_train)

# Making predictions on the test data
y_pred = model.predict(X_test)

# Calculating evaluation metrics
accuracy = accuracy_score(y_pred, y_test)
print("Accuracy: ", accuracy)
conf_matrix = confusion_matrix(y_pred, y_test)
print("Confusion Matrix: ", conf_matrix)
# Out:
# Accuracy:  0.6153846153846154
# Confusion Matrix:  [[23 17]
#  [18 33]]
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# Observation Table

# %%
import pandas as pd

features = [
    "age, trestbps",
    "age, chol",
    "age, thalach",
    "trestbps, thalach",
    "chol, thalach"
]

results = {
    "Model": ["Model 1", "Model 2", "Model 3", "Model 4", "Model 5"],
    "Features": features,
    "Precision": [0.6470588235294118, 0.6909090909090909, 0.6938775510204082, 0.7017543859649122, 0.7090909090909091],
    "Recall": [0.66, 0.76, 0.68, 0.8, 0.78],
    "Accuracy": [0.6153846153846154, 0.6813186813186813, 0.6593406593406593, 0.7032967032967034, 0.7032967032967034],
    "F1-Score": [0.6534653465346535, 0.7238095238095238, 0.686868686868687, 0.7476635514018691, 0.7428571428571428]
}

df = pd.DataFrame(results)

df.set_index('Model', inplace=True)

print(df)
# Out:
#                   Features  Precision  Recall  Accuracy  F1-Score
# Model
# Model 1      age, trestbps   0.647059    0.66  0.615385  0.653465
# Model 2          age, chol   0.690909    0.76  0.681319  0.723810
# Model 3       age, thalach   0.693878    0.68  0.659341  0.686869
# Model 4  trestbps, thalach   0.701754    0.80  0.703297  0.747664
# Model 5      chol, thalach   0.709091    0.78  0.703297  0.742857
